# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movement = pd.read_csv('Global_Mobility_Report.csv')
# Out:
# C:\Users\Family\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
movement.head()
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# 0  2020-02-15                                                0.0
# 1  2020-02-16                                                1.0
# 2  2020-02-17                                               -1.0
# 3  2020-02-18                                               -2.0
# 4  2020-02-19                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# ...

# %%
x = movement.date
y = movement.retail_and_recreation_percent_change_from_baseline
plt.plot(x,y)
plt.show()

# %%
movement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458565 entries, 0 to 458564
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   country_region_code                                 457777 non-null  object
#  1   country_region                                      458565 non-null  object
#  2   sub_region_1                                        445233 non-null  object
#  3   sub_region_2                                        265611 non-null  object
#  4   date                                                458565 non-null  object
#  5   retail_and_recreation_percent_change_from_baseline  358425 non-null  float64
#  6   grocery_and_pharmacy_percent_change_from_baseline   345821 non-null  float64
#  7   parks_percent_change_from_baseline                  212781 non-null  float64
# ...

# %%
mClean = movement.drop('sub_region_1', axis = 1)
mClean = mClean.drop('sub_region_2', axis = 1)
mClean.head()
# Out:
#   country_region_code        country_region        date  \
# 0                  AE  United Arab Emirates  2020-02-15
# 1                  AE  United Arab Emirates  2020-02-16
# 2                  AE  United Arab Emirates  2020-02-17
# 3                  AE  United Arab Emirates  2020-02-18
# 4                  AE  United Arab Emirates  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                0.0
# 1                                                1.0
# 2                                               -1.0
# 3                                               -2.0
# 4                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
# 3                                                1.0
# ...

# %%
mClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458565 entries, 0 to 458564
# Data columns (total 9 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   country_region_code                                 457777 non-null  object
#  1   country_region                                      458565 non-null  object
#  2   date                                                458565 non-null  object
#  3   retail_and_recreation_percent_change_from_baseline  358425 non-null  float64
#  4   grocery_and_pharmacy_percent_change_from_baseline   345821 non-null  float64
#  5   parks_percent_change_from_baseline                  212781 non-null  float64
#  6   transit_stations_percent_change_from_baseline       244044 non-null  float64
#  7   workplaces_percent_change_from_baseline             445735 non-null  float64
# ...

# %%
mClean = mClean.dropna()
mClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167092 entries, 0 to 457889
# Data columns (total 9 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   country_region_code                                 167092 non-null  object
#  1   country_region                                      167092 non-null  object
#  2   date                                                167092 non-null  object
#  3   retail_and_recreation_percent_change_from_baseline  167092 non-null  float64
#  4   grocery_and_pharmacy_percent_change_from_baseline   167092 non-null  float64
#  5   parks_percent_change_from_baseline                  167092 non-null  float64
#  6   transit_stations_percent_change_from_baseline       167092 non-null  float64
#  7   workplaces_percent_change_from_baseline             167092 non-null  float64
# ...

# %%
x = mClean.date
y = mClean.retail_and_recreation_percent_change_from_baseline
plt.plot(x,y)
plt.show()

# %%
covid_cases = pd.read_csv('time_series_covid_19_confirmed_global.csv')

# %%
covid_cases.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/20/20  5/21/20  5/22/20  5/23/20  \
# 0        0        0        0  ...     8145     8676     9216     9998
# 1        0        0        0  ...      964      969      981      989
# 2        0        0        0  ...     7542     7728     7918     8113
# 3        0        0        0  ...      762      762      762      762
# 4        0        0        0  ...       52       58       60       61
#
#    5/24/20  5/25/20  5/26/20  5/27/20  5/28/20  5/29/20
# ...

# %%
covid_cases_clean = covid_cases.drop('Province/State', axis = 1)
covid_cases_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 132 entries, Country/Region to 5/29/20
# dtypes: float64(2), int64(129), object(1)
# memory usage: 274.4+ KB

# %%
covid_deaths = pd.read_csv('provisional_covid_19_death_counts_by_sex_age_and_week.csv')

# %%
covid_deaths.head()
# Out:
#    Data as of          State  MMWR Week Week ending Date      Sex  \
# 0  05/28/2020  United States          5       02/01/2020  All Sex
# 1  05/28/2020  United States          5       02/01/2020  All Sex
# 2  05/28/2020  United States          5       02/01/2020  All Sex
# 3  05/28/2020  United States          5       02/01/2020  All Sex
# 4  05/28/2020  United States          5       02/01/2020  All Sex
#
#       Age Group  Total Deaths  COVID-19 Deaths
# 0  Under 1 year           366                0
# 1     1-4 years            63                0
# 2    5-14 years           110                0
# 3   15-24 years           563                0
# 4   25-34 years          1112                0

# %%
healthconditions = pd.read_csv('conditions_contributing_to_deaths_involving_covid_19_us.csv')

# %%
healthconditions.head()
# Out:
#    Data as of  Start Week    End Week       Condition Group  \
# 0  05/28/2020  02/01/2020  05/23/2020      Coronavirus 2019
# 1  05/28/2020  02/01/2020  05/23/2020  Respiratory diseases
# 2  05/28/2020  02/01/2020  05/23/2020  Respiratory diseases
# 3  05/28/2020  02/01/2020  05/23/2020  Respiratory diseases
# 4  05/28/2020  02/01/2020  05/23/2020  Respiratory diseases
#
#                              Condition ICD10_codes  All ages  0-24 years  \
# 0                     Coronavirus 2019        U071     82404         114
# 1              Influenza and pneumonia     J09-J18     34961          43
# 2   Chronic lower respiratory diseases     J40-J47      6598           8
# 3  Adult respiratory distress syndrome         J80     12621          30
# 4                  Respiratory failure         J96     28204          35
#
#    25-34 years  35-44 years  45-54 years  55-64 years  65-74 years  \
# 0          551         1420         3947         9901        17202
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-17-cbdc392b75dc> in <module>
# ----> 1 usimports = pd.read_excel('covid_19_us_imports_and_tariffs.xlsx')
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# ...

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Family\Anaconda3
#
#   added / updated specs:
#     - xlrd
#
#
# The following NEW packages will be INSTALLED:
#
#   xlrd               pkgs/main/win-64::xlrd-1.2.0-py37_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
